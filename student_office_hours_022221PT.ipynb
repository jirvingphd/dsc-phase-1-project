# %% [markdown]
# # Phase 1 Project Office Hours

# %% [markdown]
# - onl01-dtsc-pt-022221
# - 04/13/21

# %% [markdown]
# ## Questions?

# %% [markdown]
# ___

# %% [markdown]
# # How to Make a Successful Movie

# %% [markdown]
# * Student name: James M. Irving
# * Student pace: full time
# * Scheduled project review date/time: TBD
# * Instructor name: Life
# * Blog post URL: TBD

# %% [markdown]
# <img src="images/theatre-background-color-crop.jpg">

# %% [markdown]
# ## Overview

# %% [markdown]
# This project analyzes attributes of successfull movies from the last decade in order to identify traits of successfull films.

# %% [markdown]
# ## Business Problem

# %% [markdown]
# > Microsoft has decided to create a new movie studio, but they don’t know anything about creating movies.
# The goal of this analysis is to explore what types of films are currently doing the best at the box office, and to provide actionable recommendations to Microsoft on what type of files to create or to avoid.

# %% [markdown]
# ## Business Questions to Answer

# %% [markdown]
# - Q1: What genre has the highest median revenue?
#     - Is this different if I use ROI instead of revenue?
# - Q2: Does release month have an effect on revenue?
# - Q3: Is there a relationship between budget and ratings?

# %% [markdown]
# ## Data Understanding & Prep

# %% [markdown]
# ### Imports & Functions

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from matplotlib.ticker import FuncFormatter

import os, glob
import numpy as np
## Set pandas options
pd.set_option('display.max_columns',0)
pd.set_option('display.float_format',lambda x: f"{x:,.2f}")

## Set figure aesthetics
# sns.set_style('dark')=
plt.rcParams['figure.figsize'] = (10,4)
plt.style.use('seaborn-talk')
plt.style.use('dark_background')

## Creating color palettes
palette_muted = sns.color_palette('muted')
palette_dark = sns.color_palette('dark')

# %%
def check_nulls(df):
    """Returns a dataframe of null value counts and % null"""
    nulls = pd.DataFrame({'# Null':df.isna().sum(),
                 '% Null': (df.isna().sum()/len(df)*100).round(2)})
    return nulls


def millions(x,pos):
    """function for use wth matplotlib FuncFormatter -  formats money in millions"""
    return f"$ {x*1e-6:,}M"

def billions(x,pos):
    """function for use wth matplotlib FuncFormatter -  formats money in billions"""
    return f"$ {x*1e-9:,}B"


def get_funcformatter(kind='m'):
    """Returns a matplotlib FuncFormatter for formatting currecny in millions or billions
    
    Args:
        kind (str): which order of magnitude to use. Default is 'm'. 
                    m=Millions, b=Billions
    """
    if kind.lower()=='m':
        func = millions
    elif kind.lower()=='b':
        func = billions
    return FuncFormatter(func)

# %% [markdown]
# ### Selecting Our Data

# %% [markdown]
# - Microsoft provided 11 csv files with movie info that they suggested we use. Below we loaded all provided tables and previewed them to determine the ideal data sources to use.

# %%
## Files provided by microsoft
files = glob.glob('zippedData/*.csv*')

## Load all files into a dict using their filename as key
tables = {}
dashes='---'*25

for file in files:
    ## Save a variable-friendly version of the file name
    table_name = file.replace('.csv.gz','').split('/')[-1].replace('.','_')
    print(dashes)
    
    ## Load and preview dataframe
    print(f"Preview of {table_name}")
    tables[table_name] = pd.read_csv(file)
    display(tables[table_name].head(5))
    print()
# Out:
# ---------------------------------------------------------------------------
# Preview of imdb_title_crew
#       tconst                      directors              writers
# 0  tt0285252                      nm0899854            nm0899854
# 1  tt0438973                            NaN  nm0175726,nm1802864
# 2  tt0462036                      nm1940585            nm1940585
# 3  tt0835418                      nm0151540  nm0310087,nm0841532
# 4  tt0878654  nm0089502,nm2291498,nm2292011            nm0284943
# ---------------------------------------------------------------------------
# Preview of tmdb_movies
#    Unnamed: 0            genre_ids  ...  vote_average vote_count
# 0           0      [12, 14, 10751]  ...          7.70      10788
# 1           1  [14, 12, 16, 10751]  ...          7.70       7610
# 2           2        [12, 28, 878]  ...          6.80      12368
# 3           3      [16, 35, 10751]  ...          7.90      10174
# 4           4        [28, 878, 12]  ...          8.30      22186
#
# [5 rows x 10 columns]
# ---------------------------------------------------------------------------
# Preview of imdb_title_akas
#     title_id  ordering  ...   attributes is_original_title
# 0  tt0369610        10  ...          NaN              0.00
# 1  tt0369610        11  ...          NaN              0.00
# 2  tt0369610        12  ...          NaN              0.00
# 3  tt0369610        13  ...  short title              0.00
# 4  tt0369610        14  ...          NaN              0.00
#
# [5 rows x 8 columns]
# ---------------------------------------------------------------------------
# Preview of imdb_title_ratings
#        tconst  averagerating  numvotes
# 0  tt10356526           8.30        31
# 1  tt10384606           8.90       559
# 2   tt1042974           6.40        20
# 3   tt1043726           4.20     50352
# 4   tt1060240           6.50        21
# ---------------------------------------------------------------------------
# Preview of imdb_name_basics
#       nconst  ...                         known_for_titles
# 0  nm0061671  ...  tt0837562,tt2398241,tt0844471,tt0118553
# 1  nm0061865  ...  tt0896534,tt6791238,tt0287072,tt1682940
# 2  nm0062070  ...  tt1470654,tt0363631,tt0104030,tt0102898
# 3  nm0062195  ...  tt0114371,tt2004304,tt1618448,tt1224387
# 4  nm0062798  ...  tt0452644,tt0452692,tt3458030,tt2178256
#
# [5 rows x 6 columns]
# ---------------------------------------------------------------------------
# Preview of imdb_title_basics
#       tconst  ...                genres
# 0  tt0063540  ...    Action,Crime,Drama
# 1  tt0066787  ...       Biography,Drama
# 2  tt0069049  ...                 Drama
# 3  tt0069204  ...          Comedy,Drama
# 4  tt0100275  ...  Comedy,Drama,Fantasy
#
# [5 rows x 6 columns]
# ---------------------------------------------------------------------------
# Preview of tn_movie_budgets
#    id  release_date  ... domestic_gross worldwide_gross
# 0   1  Dec 18, 2009  ...   $760,507,625  $2,776,345,279
# 1   2  May 20, 2011  ...   $241,063,875  $1,045,663,875
# 2   3   Jun 7, 2019  ...    $42,762,350    $149,762,350
# 3   4   May 1, 2015  ...   $459,005,868  $1,403,013,963
# 4   5  Dec 15, 2017  ...   $620,181,382  $1,316,721,747
#
# [5 rows x 6 columns]
# ---------------------------------------------------------------------------
# Preview of bom_movie_gross
#                                          title studio  ...  foreign_gross  year
# 0                                  Toy Story 3     BV  ...      652000000  2010
# 1                   Alice in Wonderland (2010)     BV  ...      691300000  2010
# 2  Harry Potter and the Deathly Hallows Part 1     WB  ...      664300000  2010
# 3                                    Inception     WB  ...      535700000  2010
# 4                          Shrek Forever After   P/DW  ...      513900000  2010
#
# [5 rows x 5 columns]
# ---------------------------------------------------------------------------
# Preview of imdb_title_principals
#       tconst  ordering     nconst  category       job        characters
# 0  tt0111414         1  nm0246005     actor       NaN       ["The Man"]
# 1  tt0111414         2  nm0398271  director       NaN               NaN
# 2  tt0111414         3  nm3739909  producer  producer               NaN
# 3  tt0323808        10  nm0059247    editor       NaN               NaN
# 4  tt0323808         1  nm3579312   actress       NaN  ["Beth Boothby"]

# %% [markdown]
# The tables we ultimately used were the following:
# -  `tn_movie_budgets` for the financial data, including production budget.
# - `imdb_title_basics` for the basic information on runtime and genres.

# %% [markdown]
# ## Cleaning the Selected Data

# %%
df2 = tables['bom_movie_gross'].copy()
df2
# Out:
#                                             title  ...  year
# 0                                     Toy Story 3  ...  2010
# 1                      Alice in Wonderland (2010)  ...  2010
# 2     Harry Potter and the Deathly Hallows Part 1  ...  2010
# 3                                       Inception  ...  2010
# 4                             Shrek Forever After  ...  2010
# ...                                           ...  ...   ...
# 3382                                    The Quake  ...  2018
# 3383                  Edward II (2018 re-release)  ...  2018
# 3384                                     El Pacto  ...  2018
# 3385                                     The Swan  ...  2018
# 3386                            An Actor Prepares  ...  2018
#
# [3387 rows x 5 columns]

# %%
# tables['imdb_title_basics']

# %%
from string import punctuation
punctuation
# Out:
# '!"#$%&\'()*+,-./:;<=>?@[\\]^_`{|}~'

# %%
# %time
for punc in punctuation:
    df2['title'] = df2['title'].str.replace(punc,'')
df2.head()
# Out:
# CPU times: user 3 µs, sys: 1 µs, total: 4 µs
# Wall time: 6.91 µs
#                                          title studio  ...  foreign_gross  year
# 0                                  Toy Story 3     BV  ...      652000000  2010
# 1                     Alice in Wonderland 2010     BV  ...      691300000  2010
# 2  Harry Potter and the Deathly Hallows Part 1     WB  ...      664300000  2010
# 3                                    Inception     WB  ...      535700000  2010
# 4                          Shrek Forever After   P/DW  ...      513900000  2010
#
# [5 rows x 5 columns]

# %%
df2 = tables['bom_movie_gross']
df2
# Out:
#                                             title  ...  year
# 0                                     Toy Story 3  ...  2010
# 1                      Alice in Wonderland (2010)  ...  2010
# 2     Harry Potter and the Deathly Hallows Part 1  ...  2010
# 3                                       Inception  ...  2010
# 4                             Shrek Forever After  ...  2010
# ...                                           ...  ...   ...
# 3382                                    The Quake  ...  2018
# 3383                  Edward II (2018 re-release)  ...  2018
# 3384                                     El Pacto  ...  2018
# 3385                                     The Swan  ...  2018
# 3386                            An Actor Prepares  ...  2018
#
# [3387 rows x 5 columns]

# %%
# %time
from string import punctuation
def remove_punc(x):
    
    for punc in punctuation:
        x = x.replace(punc,'')
    return x

df2['title'] = df2['title'].apply(remove_punc)
df2.head()
# Out:
# CPU times: user 3 µs, sys: 1e+03 ns, total: 4 µs
# Wall time: 6.91 µs
#                                          title studio  ...  foreign_gross  year
# 0                                  Toy Story 3     BV  ...      652000000  2010
# 1                     Alice in Wonderland 2010     BV  ...      691300000  2010
# 2  Harry Potter and the Deathly Hallows Part 1     WB  ...      664300000  2010
# 3                                    Inception     WB  ...      535700000  2010
# 4                          Shrek Forever After   P/DW  ...      513900000  2010
#
# [5 rows x 5 columns]

# %%
def apply_to_rows(row):
    if row['studio']  == 'BV':
        row['is_disney'] = True
    else:
        row['is_disney'] = False
    return row

df2.apply(apply_to_rows,  axis=1)
# Out:
#                                             title      studio  ...  year is_disney
# 0                                     Toy Story 3          BV  ...  2010      True
# 1                        Alice in Wonderland 2010          BV  ...  2010      True
# 2     Harry Potter and the Deathly Hallows Part 1          WB  ...  2010     False
# 3                                       Inception          WB  ...  2010     False
# 4                             Shrek Forever After        P/DW  ...  2010     False
# ...                                           ...         ...  ...   ...       ...
# 3382                                    The Quake       Magn.  ...  2018     False
# 3383                     Edward II 2018 rerelease          FM  ...  2018     False
# 3384                                     El Pacto        Sony  ...  2018     False
# 3385                                     The Swan  Synergetic  ...  2018     False
# 3386                            An Actor Prepares       Grav.  ...  2018     False
#
# [3387 rows x 6 columns]

# %%
tables['tn_movie_budgets'].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5782 entries, 0 to 5781
# Data columns (total 6 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   id                 5782 non-null   int64
#  1   release_date       5782 non-null   object
#  2   movie              5782 non-null   object
#  3   production_budget  5782 non-null   object
#  4   domestic_gross     5782 non-null   object
#  5   worldwide_gross    5782 non-null   object
# dtypes: int64(1), object(5)
# memory usage: 271.2+ KB

# %%
tables['bom_movie_gross'].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3387 entries, 0 to 3386
# Data columns (total 5 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   title           3387 non-null   object
#  1   studio          3382 non-null   object
#  2   domestic_gross  3359 non-null   float64
#  3   foreign_gross   2037 non-null   object
#  4   year            3387 non-null   int64
# dtypes: float64(1), int64(1), object(3)
# memory usage: 132.4+ KB

# %% [markdown]
# ### Cleaning `tn_movie_budgets`

# %%
## copy table 
df = tables['tn_movie_budgets'].copy()
df
# Out:
#       id  release_date  ... domestic_gross worldwide_gross
# 0      1  Dec 18, 2009  ...   $760,507,625  $2,776,345,279
# 1      2  May 20, 2011  ...   $241,063,875  $1,045,663,875
# 2      3   Jun 7, 2019  ...    $42,762,350    $149,762,350
# 3      4   May 1, 2015  ...   $459,005,868  $1,403,013,963
# 4      5  Dec 15, 2017  ...   $620,181,382  $1,316,721,747
# ...   ..           ...  ...            ...             ...
# 5777  78  Dec 31, 2018  ...             $0              $0
# 5778  79   Apr 2, 1999  ...        $48,482        $240,495
# 5779  80  Jul 13, 2005  ...         $1,338          $1,338
# 5780  81  Sep 29, 2015  ...             $0              $0
# 5781  82   Aug 5, 2005  ...       $181,041        $181,041
#
# [5782 rows x 6 columns]

# %%
## Check df info
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5782 entries, 0 to 5781
# Data columns (total 6 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   id                 5782 non-null   int64
#  1   release_date       5782 non-null   object
#  2   movie              5782 non-null   object
#  3   production_budget  5782 non-null   object
#  4   domestic_gross     5782 non-null   object
#  5   worldwide_gross    5782 non-null   object
# dtypes: int64(1), object(5)
# memory usage: 271.2+ KB

# %%
## Check nulls
check_nulls(df)
# Out:
#                    # Null  % Null
# id                      0    0.00
# release_date            0    0.00
# movie                   0    0.00
# production_budget       0    0.00
# domestic_gross          0    0.00
# worldwide_gross         0    0.00

# %% [markdown]
# #### Notes on tn_movie_budgets:
# - Financial columns are strings
# - no null values to worry about.
# - release_date could be converted to datetime

# %%
## Testing convert production_budget
df['production_budget'].map(lambda x: x.replace('$','').replace(',',''))
# Out:
# 0       425000000
# 1       410600000
# 2       350000000
# 3       330600000
# 4       317000000
#           ...
# 5777         7000
# 5778         6000
# 5779         5000
# 5780         1400
# 5781         1100
# Name: production_budget, Length: 5782, dtype: object

# %%
## What is the % null?
(df.isna().sum()/len(df)*100)
# Out:
# id                  0.00
# release_date        0.00
# movie               0.00
# production_budget   0.00
# domestic_gross      0.00
# worldwide_gross     0.00
# dtype: float64

# %%
## Convert Money Columns to Floats
for col in ['production_budget','domestic_gross','worldwide_gross']:
    df[col] = df[col].map(lambda x: x.replace('$','').replace(',','')).astype(float)
df
# Out:
#       id  release_date  ... domestic_gross  worldwide_gross
# 0      1  Dec 18, 2009  ... 760,507,625.00 2,776,345,279.00
# 1      2  May 20, 2011  ... 241,063,875.00 1,045,663,875.00
# 2      3   Jun 7, 2019  ...  42,762,350.00   149,762,350.00
# 3      4   May 1, 2015  ... 459,005,868.00 1,403,013,963.00
# 4      5  Dec 15, 2017  ... 620,181,382.00 1,316,721,747.00
# ...   ..           ...  ...            ...              ...
# 5777  78  Dec 31, 2018  ...           0.00             0.00
# 5778  79   Apr 2, 1999  ...      48,482.00       240,495.00
# 5779  80  Jul 13, 2005  ...       1,338.00         1,338.00
# 5780  81  Sep 29, 2015  ...           0.00             0.00
# 5781  82   Aug 5, 2005  ...     181,041.00       181,041.00
#
# [5782 rows x 6 columns]

# %%
## Make a folder for the clean data
FOLDER = './cleaned_data/'
os.makedirs(FOLDER, exist_ok=True)

# %%
## Save clean_csv 
df.to_csv(f"{FOLDER}tn_movie_budgets_clean.csv",index=False)

# %%
## Load back in the clean tn_movie_budgets with release dates as datetime dtype
tn_movie_budgets = pd.read_csv("cleaned_data/tn_movie_budgets_clean.csv", 
                               parse_dates=['release_date'])
tn_movie_budgets['release_date'].dt.quarter
# Out:
# 0       4
# 1       2
# 2       2
# 3       2
# 4       4
#        ..
# 5777    4
# 5778    2
# 5779    3
# 5780    3
# 5781    3
# Name: release_date, Length: 5782, dtype: int64

# %% [markdown]
# ### Cleaning `imdb_title_basics`

# %%
df = tables['imdb_title_basics'].copy()
df
# Out:
#            tconst  ...                genres
# 0       tt0063540  ...    Action,Crime,Drama
# 1       tt0066787  ...       Biography,Drama
# 2       tt0069049  ...                 Drama
# 3       tt0069204  ...          Comedy,Drama
# 4       tt0100275  ...  Comedy,Drama,Fantasy
# ...           ...  ...                   ...
# 146139  tt9916538  ...                 Drama
# 146140  tt9916622  ...           Documentary
# 146141  tt9916706  ...                Comedy
# 146142  tt9916730  ...                   NaN
# 146143  tt9916754  ...           Documentary
#
# [146144 rows x 6 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 146144 entries, 0 to 146143
# Data columns (total 6 columns):
#  #   Column           Non-Null Count   Dtype
# ---  ------           --------------   -----
#  0   tconst           146144 non-null  object
#  1   primary_title    146144 non-null  object
#  2   original_title   146123 non-null  object
#  3   start_year       146144 non-null  int64
#  4   runtime_minutes  114405 non-null  float64
#  5   genres           140736 non-null  object
# dtypes: float64(1), int64(1), object(4)
# memory usage: 6.7+ MB

# %%
check_nulls(df)
# Out:
#                  # Null  % Null
# tconst                0    0.00
# primary_title         0    0.00
# original_title       21    0.01
# start_year            0    0.00
# runtime_minutes   31739   21.72
# genres             5408    3.70

# %% [markdown]
# #### Notes on `imdb_title_basics`
# - Contains genres but in as a string with multiple genres combined
#     - Separate genres
# - Large Number of Nulls from runtime_minutes (~22%)
#     - Potentially drop them OR
#     - Fill in with median?
#
# - Some nulls in genre.
#     - As long as no big-name movies missing genres -> drop nulls from genres

# %%
## What movies are missing genre
null_genres = df[df['genres'].isna()].sort_values('start_year')
display(null_genres.head(10), null_genres.tail(10))
# Out:
#            tconst              primary_title  ... runtime_minutes  genres
# 18738   tt1819635                      Ocaso  ...           80.00     NaN
# 123475  tt7493048               Zoi podilato  ...             nan     NaN
# 31823   tt2200832              Beyond Belief  ...           80.00     NaN
# 110268  tt6448910             Febiofest 2010  ...             nan     NaN
# 10616   tt1604602           Running on Empty  ...           80.00     NaN
# 110263  tt6448882            Hu Wang Gui Lai  ...             nan     NaN
# 32354   tt2217494  Art of the Japanese Sword  ...           83.00     NaN
# 10681   tt1606611        Hitoya ni saku hana  ...             nan     NaN
# 110255  tt6448850         Indie-AniFest 2010  ...             nan     NaN
# 11065   tt1619045      The HIV Story Project  ...             nan     NaN
#
# [10 rows x 6 columns]
#             tconst  ... genres
# 3015    tt10304138  ...    NaN
# 2904    tt10298810  ...    NaN
# 3016    tt10304140  ...    NaN
# 3017    tt10304142  ...    NaN
# 3018    tt10304194  ...    NaN
# 135475   tt8582042  ...    NaN
# 2905    tt10298840  ...    NaN
# 111226   tt6495056  ...    NaN
# 2906    tt10298848  ...    NaN
# 2948    tt10300396  ...    NaN
#
# [10 rows x 6 columns]

# %% [markdown]
# >- Some movies without genre are unreleased, others seem to be foreigh or indie/niche.
#     - Drop nulls from genre

# %%
## remove unreleased movies
df = df[df['start_year']<2021]
df
# Out:
#            tconst  ...                genres
# 0       tt0063540  ...    Action,Crime,Drama
# 1       tt0066787  ...       Biography,Drama
# 2       tt0069049  ...                 Drama
# 3       tt0069204  ...          Comedy,Drama
# 4       tt0100275  ...  Comedy,Drama,Fantasy
# ...           ...  ...                   ...
# 146139  tt9916538  ...                 Drama
# 146140  tt9916622  ...           Documentary
# 146141  tt9916706  ...                Comedy
# 146142  tt9916730  ...                   NaN
# 146143  tt9916754  ...           Documentary
#
# [146018 rows x 6 columns]

# %%
## Drop remaining nulls from genre
df = df.dropna(subset=['genres'])
df
# Out:
#            tconst  ...                 genres
# 0       tt0063540  ...     Action,Crime,Drama
# 1       tt0066787  ...        Biography,Drama
# 2       tt0069049  ...                  Drama
# 3       tt0069204  ...           Comedy,Drama
# 4       tt0100275  ...   Comedy,Drama,Fantasy
# ...           ...  ...                    ...
# 146138  tt9916428  ...  Adventure,History,War
# 146139  tt9916538  ...                  Drama
# 146140  tt9916622  ...            Documentary
# 146141  tt9916706  ...                 Comedy
# 146143  tt9916754  ...            Documentary
#
# [140622 rows x 6 columns]

# %%
## delete nulls df
del null_genres

# %%
## Check movies missing run_time, sort by start-year
null_df = df[df['runtime_minutes'].isna()].sort_values('start_year')
display(null_df.head(10),null_df.tail(10))
# Out:
#            tconst  ...              genres
# 54585   tt3208228  ...               Drama
# 64327   tt3688022  ...  Comedy,Documentary
# 17146   tt1777046  ...        Drama,Horror
# 64332   tt3688314  ...         Documentary
# 6948    tt1354720  ...               Drama
# 123783  tt7520478  ...         Crime,Drama
# 64385   tt3690096  ...               Drama
# 17109   tt1776272  ...              Action
# 17084   tt1776147  ...               Drama
# 6998    tt1364277  ...      Comedy,Western
#
# [10 rows x 6 columns]
#             tconst  ...                      genres
# 3207    tt10319486  ...               Action,Comedy
# 140300   tt9093890  ...                       Drama
# 114869   tt6802400  ...                      Comedy
# 4185    tt10393488  ...                    Thriller
# 123765   tt7518786  ...       Biography,Drama,Sport
# 3206    tt10319442  ...                       Crime
# 102492   tt5996648  ...     Animation,Comedy,Family
# 135910   tt8638636  ...             Sci-Fi,Thriller
# 119125   tt7146812  ...  Adventure,Animation,Comedy
# 121769   tt7350404  ...                       Drama
#
# [10 rows x 6 columns]

# %%
## Drop the one missing original title
df = df.dropna(subset=['original_title'])
df
# Out:
#            tconst  ...                 genres
# 0       tt0063540  ...     Action,Crime,Drama
# 1       tt0066787  ...        Biography,Drama
# 2       tt0069049  ...                  Drama
# 3       tt0069204  ...           Comedy,Drama
# 4       tt0100275  ...   Comedy,Drama,Fantasy
# ...           ...  ...                    ...
# 146138  tt9916428  ...  Adventure,History,War
# 146139  tt9916538  ...                  Drama
# 146140  tt9916622  ...            Documentary
# 146141  tt9916706  ...                 Comedy
# 146143  tt9916754  ...            Documentary
#
# [140620 rows x 6 columns]

# %%
## final null check
check_nulls(df)
# Out:
#                  # Null  % Null
# tconst                0    0.00
# primary_title         0    0.00
# original_title        0    0.00
# start_year            0    0.00
# runtime_minutes   28395   20.19
# genres                0    0.00

# %%
## Save and reload csv
filename = f"{FOLDER}imdb_title_basics_clean.csv"
df.to_csv(filename,index=False)
imdb_title_basics = pd.read_csv(filename)
imdb_title_basics.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 140620 entries, 0 to 140619
# Data columns (total 6 columns):
#  #   Column           Non-Null Count   Dtype
# ---  ------           --------------   -----
#  0   tconst           140620 non-null  object
#  1   primary_title    140620 non-null  object
#  2   original_title   140620 non-null  object
#  3   start_year       140620 non-null  int64
#  4   runtime_minutes  112225 non-null  float64
#  5   genres           140620 non-null  object
# dtypes: float64(1), int64(1), object(4)
# memory usage: 6.4+ MB

# %% [markdown]
# ### Merging the Data:
# - `tn_movie_budgets` & `imdb_title_basics`

# %%
## Preview before merging
display(tn_movie_budgets.head(3),imdb_title_basics.head(3))
# Out:
#    id release_date  ... domestic_gross  worldwide_gross
# 0   1   2009-12-18  ... 760,507,625.00 2,776,345,279.00
# 1   2   2011-05-20  ... 241,063,875.00 1,045,663,875.00
# 2   3   2019-06-07  ...  42,762,350.00   149,762,350.00
#
# [3 rows x 6 columns]
#       tconst  ...              genres
# 0  tt0063540  ...  Action,Crime,Drama
# 1  tt0066787  ...     Biography,Drama
# 2  tt0069049  ...               Drama
#
# [3 rows x 6 columns]

# %% [markdown]
# - Merge using the movie names
#     - left table:
#         - tn_movie_budgets
#         - on = "movie"
#     - right table;
#         - imdb_title_basics
#         - on = ...original_title?

# %%
df = pd.merge(tn_movie_budgets,imdb_title_basics,left_on='movie',
         right_on='original_title')
df
# Out:
#       id release_date  ... runtime_minutes                    genres
# 0      2   2011-05-20  ...          136.00  Action,Adventure,Fantasy
# 1      3   2019-06-07  ...          113.00   Action,Adventure,Sci-Fi
# 2      4   2015-05-01  ...          141.00   Action,Adventure,Sci-Fi
# 3      7   2018-04-27  ...          149.00   Action,Adventure,Sci-Fi
# 4      9   2017-11-17  ...          120.00  Action,Adventure,Fantasy
# ...   ..          ...  ...             ...                       ...
# 3462  67   2006-04-28  ...           70.00       Comedy,Drama,Horror
# 3463  68   2001-07-06  ...           93.00                     Drama
# 3464  73   2012-01-13  ...           95.00              Comedy,Drama
# 3465  78   2018-12-31  ...           77.00    Horror,Sci-Fi,Thriller
# 3466  81   2015-09-29  ...           76.00     Drama,Horror,Thriller
#
# [3467 rows x 12 columns]

# %%
df.isna().sum()
# Out:
# id                     0
# release_date           0
# movie                  0
# production_budget      0
# domestic_gross         0
# worldwide_gross        0
# tconst                 0
# primary_title          0
# original_title         0
# start_year             0
# runtime_minutes      411
# genres                 0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3467 entries, 0 to 3466
# Data columns (total 12 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   id                 3467 non-null   int64
#  1   release_date       3467 non-null   datetime64[ns]
#  2   movie              3467 non-null   object
#  3   production_budget  3467 non-null   float64
#  4   domestic_gross     3467 non-null   float64
#  5   worldwide_gross    3467 non-null   float64
#  6   tconst             3467 non-null   object
#  7   primary_title      3467 non-null   object
#  8   original_title     3467 non-null   object
#  9   start_year         3467 non-null   int64
#  10  runtime_minutes    3056 non-null   float64
#  11  genres             3467 non-null   object
# dtypes: datetime64[ns](1), float64(4), int64(2), object(5)
# memory usage: 352.1+ KB

# %%
check_nulls(df)
# Out:
#                    # Null  % Null
# id                      0    0.00
# release_date            0    0.00
# movie                   0    0.00
# production_budget       0    0.00
# domestic_gross          0    0.00
# worldwide_gross         0    0.00
# tconst                  0    0.00
# primary_title           0    0.00
# original_title          0    0.00
# start_year              0    0.00
# runtime_minutes       411   11.85
# genres                  0    0.00

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3467 entries, 0 to 3466
# Data columns (total 12 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   id                 3467 non-null   int64
#  1   release_date       3467 non-null   datetime64[ns]
#  2   movie              3467 non-null   object
#  3   production_budget  3467 non-null   float64
#  4   domestic_gross     3467 non-null   float64
#  5   worldwide_gross    3467 non-null   float64
#  6   tconst             3467 non-null   object
#  7   primary_title      3467 non-null   object
#  8   original_title     3467 non-null   object
#  9   start_year         3467 non-null   int64
#  10  runtime_minutes    3056 non-null   float64
#  11  genres             3467 non-null   object
# dtypes: datetime64[ns](1), float64(4), int64(2), object(5)
# memory usage: 352.1+ KB

# %% [markdown]
# ### Save and Load Merged Dataset

# %%
file = 'cleaned_data/merged_budgets_title_basics.csv'
df.to_csv(file,index=False)
df = pd.read_csv(file, parse_dates=['release_date'])
df
# Out:
#       id release_date  ... runtime_minutes                    genres
# 0      2   2011-05-20  ...          136.00  Action,Adventure,Fantasy
# 1      3   2019-06-07  ...          113.00   Action,Adventure,Sci-Fi
# 2      4   2015-05-01  ...          141.00   Action,Adventure,Sci-Fi
# 3      7   2018-04-27  ...          149.00   Action,Adventure,Sci-Fi
# 4      9   2017-11-17  ...          120.00  Action,Adventure,Fantasy
# ...   ..          ...  ...             ...                       ...
# 3462  67   2006-04-28  ...           70.00       Comedy,Drama,Horror
# 3463  68   2001-07-06  ...           93.00                     Drama
# 3464  73   2012-01-13  ...           95.00              Comedy,Drama
# 3465  78   2018-12-31  ...           77.00    Horror,Sci-Fi,Thriller
# 3466  81   2015-09-29  ...           76.00     Drama,Horror,Thriller
#
# [3467 rows x 12 columns]

# %% [markdown]
# ## Feature Engineering

# %% [markdown]
# ### Revenue

# %%
df['revenue_domestic'] = df['domestic_gross'] - df['production_budget']
df['revenue_worldwide'] = df['worldwide_gross'] - df['production_budget']

# %%
df['lost_money'] = df['revenue_domestic']<0
df
# Out:
#       id release_date  ... revenue_worldwide  lost_money
# 0      2   2011-05-20  ...    635,063,875.00        True
# 1      3   2019-06-07  ...   -200,237,650.00        True
# 2      4   2015-05-01  ...  1,072,413,963.00       False
# 3      7   2018-04-27  ...  1,748,134,200.00       False
# 4      9   2017-11-17  ...    355,945,209.00        True
# ...   ..          ...  ...               ...         ...
# 3462  67   2006-04-28  ...        128,711.00       False
# 3463  68   2001-07-06  ...         84,596.00       False
# 3464  73   2012-01-13  ...         -4,416.00        True
# 3465  78   2018-12-31  ...         -7,000.00        True
# 3466  81   2015-09-29  ...         -1,400.00        True
#
# [3467 rows x 15 columns]

# %% [markdown]
# ### ROI

# %% [markdown]
# $$\text{ROI(%)}= \frac{\text{revenue}}{\text{investment}}*100$$

# %%
## Calculate ROI
df['roi_domestic'] = (df['revenue_domestic'] / df['production_budget'])*100
df['roi_worldwide'] = (df['revenue_worldwide'] / df['production_budget'])*100

# %% [markdown]
# ### Release Month

# %%
## making release date into datetime for month
df['release_date'] = pd.to_datetime(df['release_date'])
df['release_date'].map(lambda x: x.year)
df['release_month'] = df['release_date'].dt.month

# %% [markdown]
# ### SAVING FINAL FILE FOR CLASS

# %%
# df.to_csv('joined_movie_data_for_sg.csv',index=False)

# %% [markdown]
# ## Analysis

# %% [markdown]
# ### Q1: Which genre generates the most revenue ?

# %%
genre_str = ','.join(df['genres'])
genre_list = np.unique(genre_str.split(','))
genre_list
# Out:
# array(['Action', 'Adventure', 'Animation', 'Biography', 'Comedy', 'Crime',
#        'Documentary', 'Drama', 'Family', 'Fantasy', 'History', 'Horror',
#        'Music', 'Musical', 'Mystery', 'News', 'Reality-TV', 'Romance',
#        'Sci-Fi', 'Sport', 'Thriller', 'War', 'Western'], dtype='<U11')

# %%
df.loc[df['genres'].str.contains(genre_list[0]),'roi_worldwide']
# Out:
# 0       154.67
# 1       -57.21
# 2       324.38
# 3       582.71
# 4       118.65
#          ...
# 3395   -100.00
# 3398   -100.00
# 3414   -100.00
# 3416   -100.00
# 3426   -100.00
# Name: roi_worldwide, Length: 689, dtype: float64

# %%
genre_dict = {}
for genre in genre_list:
    genre_dict[genre] = df.loc[df['genres'].str.contains(genre),'roi_worldwide']
genre_dict.keys()
# Out:
# dict_keys(['Action', 'Adventure', 'Animation', 'Biography', 'Comedy', 'Crime', 'Documentary', 'Drama', 'Family', 'Fantasy', 'History', 'Horror', 'Music', 'Musical', 'Mystery', 'News', 'Reality-TV', 'Romance', 'Sci-Fi', 'Sport', 'Thriller', 'War', 'Western'])

# %%
df['exaple'] = df[df['genres'].str.contains(genre)]['roi_worldwide']

# %%
genre_dict = {genre:df.loc[df['genres'].str.contains(genre),
                            'roi_worldwide'] for genre in genre_list}

# %%
genre_dict['Documentary']
# Out:
# 45      412.75
# 48     -100.00
# 82        0.03
# 97      388.13
# 113      21.55
#          ...
# 3435    -83.25
# 3437   -100.00
# 3438   -100.00
# 3448    -86.86
# 3459   -100.00
# Name: roi_worldwide, Length: 465, dtype: float64

# %%
df.loc[0,'genres']
# Out:
# 'Action,Adventure,Fantasy'

# %% [markdown]
# ### A1:
# - The top 5 genres that generate the most revenue (on average) are:
#     1.
#     2.
#     3.
#     4.
#     5.

# %% [markdown]
# ### Q2: Does the release month affect worldwide revenue?

# %% [markdown]
# ### Q3: Do movies with higher budget earn more revenue?

# %% [markdown]
# ## Conclusion

# %% [markdown]
# - We analyzed over 3,000 films from the last ~10 years and found attributes of successful movies.
#
# - To recap our recommendations:
#     - We recommend that Microsoft make a movie in the Animation genre.
#     - We recommended they release their movies in December (or May).
#     - We recommend they be generous with their budgets but to not assume higher budget = more revenue.
